# %%
import pandas as pd
import numpy as np
import json

# %%
output_path = "/Users/heytitle/projects/jourd-politics/src/data"

def prepend_path(s):
    return "%s/%s" % (output_path, s)

# %%
df_projects = pd.read_csv("../data/2019-local-administrative-organization-projects.csv")

# %%
df_projects
# Out:
#        announce_date  budget_year contract_date contract_finish_date  \
# 0                  -         2561     8 พ.ย. 60          16 มี.ค. 61
# 1                  -         2561    17 ต.ค. 60           30 ก.ย. 61
# 2                  -         2561    21 ก.ย. 61           20 พ.ย. 61
# 3                  -         2561    15 ม.ค. 61           1 มี.ค. 61
# 4                  -         2561    24 ม.ค. 61           23 ก.พ. 61
# 5                  -         2561    30 ม.ค. 61           1 มี.ค. 61
# 6                  -         2561    2 เม.ย. 61            2 พ.ค. 61
# 7                  -         2561   29 มี.ค. 61           30 ก.ย. 61
# 8                  -         2561     7 พ.ค. 61           15 พ.ค. 61
# 9                  -         2561     1 ก.พ. 61           31 ก.ค. 61
# 10                 -         2561   30 มี.ค. 61           30 ก.ย. 61
# 11                 -         2561   30 มี.ค. 61           30 ก.ย. 61
# 12                 -         2561   29 มี.ค. 61           30 ก.ย. 61
# 13                 -         2561   29 มี.ค. 61           30 ก.ย. 61
# 14                 -         2561     1 ก.พ. 61           31 ก.ค. 61
# 15                 -         2561   29 มี.ค. 61           30 ก.ย. 61
# 16                 -         2561   29 มี.ค. 61           30 ก.ย. 61
# 17                 -         2561     9 ก.ค. 61           16 ก.ค. 61
# 18                 -         2561     4 พ.ค. 61           11 พ.ค. 61
# 19                 -         2561    20 ต.ค. 60           31 ต.ค. 60
# 20                 -         2561    27 ก.ย. 61            4 ต.ค. 61
# 21                 -         2561    11 ก.ย. 61           18 ก.ย. 61
# 22                 -         2561    22 พ.ค. 61           1 มิ.ย. 61
# 23                 -         2561    11 ม.ค. 61           13 ม.ค. 61
# 24                 -         2561    20 ก.ย. 61           27 ก.ย. 61
# 25                 -         2561    9 เม.ย. 61          19 เม.ย. 61
# 26                 -         2561    4 เม.ย. 61          12 เม.ย. 61
# 27                 -         2561    17 ก.ย. 61           24 ก.ย. 61
# 28                 -         2561    2 เม.ย. 61            2 พ.ค. 61
# 29                 -         2561     5 ม.ค. 61           12 ม.ค. 61
# ...              ...          ...           ...                  ...
# 790277             -         2561    24 ก.ย. 61           29 ก.ย. 61
# 790278             -         2561    21 ก.ย. 61           26 ก.ย. 61
# 790279             -         2561    14 ส.ค. 61           17 ส.ค. 61
# 790280             -         2561     8 ส.ค. 61           11 ส.ค. 61
# 790281             -         2561    3 เม.ย. 61          10 เม.ย. 61
# 790282             -         2561    19 ธ.ค. 60           24 ธ.ค. 60
# 790283             -         2561    27 ส.ค. 61            1 ก.ย. 61
# 790284             -         2561   15 มี.ค. 61          30 มี.ค. 61
# 790285             -         2561   12 มี.ค. 61          17 มี.ค. 61
# 790286             -         2561    31 ก.ค. 61            7 ส.ค. 61
# 790287             -         2561    24 พ.ค. 61           29 พ.ค. 61
# 790288             -         2561    14 ส.ค. 61           17 ส.ค. 61
# 790289             -         2561   11 มิ.ย. 61          11 มิ.ย. 61
# 790290             -         2561    25 พ.ค. 61           1 มิ.ย. 61
# 790291             -         2561    15 ส.ค. 61           22 ส.ค. 61
# 790292             -         2561    5 เม.ย. 61          14 เม.ย. 61
# 790293             -         2561    26 ก.ค. 61            2 ส.ค. 61
# 790294             -         2561    20 ก.ย. 61           21 ก.ย. 61
# 790295             -         2561    21 ส.ค. 61           26 ส.ค. 61
# 790296             -         2561    20 ก.พ. 61           23 ก.พ. 61
# 790297             -         2561    11 ก.ค. 61           12 ก.ค. 61
# 790298             -         2561   18 เม.ย. 61          23 เม.ย. 61
# 790299             -         2561   14 มิ.ย. 61          19 มิ.ย. 61
# 790300             -         2561    23 ก.ค. 61           28 ก.ค. 61
# 790301             -         2561     2 ส.ค. 61            7 ส.ค. 61
# 790302             -         2561    22 ก.พ. 61           27 ก.พ. 61
# 790303             -         2561     5 ก.ย. 61          12 มิ.ย. 61
# 790304             -         2561    21 ก.ย. 61           26 ก.ย. 61
# 790305             -         2561    18 ก.ย. 61           21 ก.ย. 61
# 790306             -         2561    27 ส.ค. 61            1 ก.ย. 61
#
#        contract_no   contract_status  \
# 0           8/2561  ระหว่างดำเนินการ
# 1           3/2561  ระหว่างดำเนินการ
# 2          62/2561  ระหว่างดำเนินการ
# 3          26/2561  ระหว่างดำเนินการ
# 4          28/2561  ระหว่างดำเนินการ
# 5          29/2561  ระหว่างดำเนินการ
# 6          45/2561  ระหว่างดำเนินการ
# 7          38/2561  ระหว่างดำเนินการ
# 8          43/2561  ระหว่างดำเนินการ
# 9          31/2561  ระหว่างดำเนินการ
# 10         44/2561  ระหว่างดำเนินการ
# 11         43/2561  ระหว่างดำเนินการ
# 12         39/2561  ระหว่างดำเนินการ
# 13         41/2561  ระหว่างดำเนินการ
# 14         30/2561  ระหว่างดำเนินการ
# 15         40/2561  ระหว่างดำเนินการ
# 16         42/2561  ระหว่างดำเนินการ
# 17         54/2561  ระหว่างดำเนินการ
# 18         44/2561  ระหว่างดำเนินการ
# 19          5/2561      สิ้นสุดสัญญา
# 20         82/2561  ระหว่างดำเนินการ
# 21         71/2561  ระหว่างดำเนินการ
# 22         49/2561  ระหว่างดำเนินการ
# 23         19/2561      สิ้นสุดสัญญา
# 24         76/2561  ระหว่างดำเนินการ
# 25         41/2561  ระหว่างดำเนินการ
# 26         33/2561  ระหว่างดำเนินการ
# 27         73/2561  ระหว่างดำเนินการ
# 28         46/2561  ระหว่างดำเนินการ
# 29         17/2561      สิ้นสุดสัญญา
# ...            ...               ...
# 790277    170/2561  ระหว่างดำเนินการ
# 790278    162/2561  ระหว่างดำเนินการ
# 790279    104/2561  ระหว่างดำเนินการ
# 790280    101/2561  ระหว่างดำเนินการ
# 790281     41/2561  ระหว่างดำเนินการ
# 790282     11/2561  ระหว่างดำเนินการ
# 790283    111/2561  ระหว่างดำเนินการ
# 790284     37/2561  ระหว่างดำเนินการ
# 790285     34/2561  ระหว่างดำเนินการ
# 790286    129/2561  ระหว่างดำเนินการ
# 790287     60/2561  ระหว่างดำเนินการ
# 790288    105/2561  ระหว่างดำเนินการ
# 790289     66/2561  ระหว่างดำเนินการ
# 790290     96/2561  ระหว่างดำเนินการ
# 790291    136/2561  ระหว่างดำเนินการ
# 790292     79/2561  ระหว่างดำเนินการ
# 790293    125/2561  ระหว่างดำเนินการ
# 790294    173/2561  ระหว่างดำเนินการ
# 790295    140/2561  ระหว่างดำเนินการ
# 790296     27/2561  ระหว่างดำเนินการ
# 790297    117/2561  ระหว่างดำเนินการ
# 790298     46/2561  ระหว่างดำเนินการ
# 790299     70/2561  ระหว่างดำเนินการ
# 790300    121/2561  ระหว่างดำเนินการ
# 790301    131/2561  ระหว่างดำเนินการ
# 790302     50/2561  ระหว่างดำเนินการ
# 790303    123/2561  ระหว่างดำเนินการ
# 790304    166/2561  ระหว่างดำเนินการ
# 790305    137/2561  ระหว่างดำเนินการ
# 790306    113/2561  ระหว่างดำเนินการ
#
#                                            corporate_name  \
# 0                       บริษัท  ทุ่งกุลาแดรี่ฟูดส์  จำกัด
# 1                                  ร้านกุ้งปาล์มปิโตเลียม
# 2                   ห้างหุ้นส่วนจำกัด ศราวุธเกษตรก่อสร้าง
# 3                                           ร้านบุญวงศ์ษา
# 4                ห้างหุ้นส่วนจำกัด คำสีจตุรพักตร์ก่อสร้าง
# 5                ห้างหุ้นส่วนจำกัด คำสีจตุรพักตร์ก่อสร้าง
# 6                                     นายประจง จันทร์จ่าย
# 7                                  นายบุญช่วย  จำปาจันทร์
# 8                             ร้านทูพัฒน์  โชคเจริญทรัพย์
# 9                              นางสาวสุชาวีร์  ไชยน้ำอ้อม
# 10                                       นายจา  จันทร์ศรี
# 11                                  นางสาวจีรนันท์  นัยลี
# 12                                   นายรัศมี  เนื้อจันทา
# 13                                      นายถาวร  ทะวะวงค์
# 14                            นายสำราญภิรมย์  กลางท่าใคร่
# 15                                   นายอภิชาติ  ดวงพิมาย
# 16                                   นายวัฒนา   เสาสูงยาง
# 17                                            ร้านโชคถาวร
# 18                                            ร้านโชคถาวร
# 19                                     หจก.เจนวิทยาสราวุธ
# 20                                          ร้านยักษ์เล็ก
# 21                                        ร้านดวงดีการค้า
# 22           บริษัท ดิจิตอล คอร์ปเปอร์เรต ซิสเต็มส์ จำกัด
# 23                                   นางเพ็ญศรี  หานามชัย
# 24                                        ร้าน วี.เอส.คอม
# 25                                         เจนวิทยาสราวุธ
# 26                                        ร้านดวงดีการค้า
# 27                                          ร้านยักษ์เล็ก
# 28                                    นายประจง จันทร์จ่าย
# 29                               บริษัท ไอที ทูเดย์ จำกัด
# ...                                                   ...
# 790277                           นางสาววราภรณ์  บำรุงพงศ์
# 790278                           นางสาววราภรณ์  บำรุงพงศ์
# 790279                  ห้างหุ้นส่วนจำกัด เซ็นจูรี่บึงกาฬ
# 790280                               พงษ์ศักดิ์ รัตน์สุพล
# 790281                                     นาง พณิฎา พยอม
# 790282                                     นาง พณิฎา พยอม
# 790283                 บริษัท บึงกาฬเฟอร์นิเจอร์ 77 จำกัด
# 790284                                       แอ้มเซอร์วิส
# 790285                                      ร้าน 239 ไอที
# 790286  ห้างหุ้นส่วนจำกัด เอ.แอนด์ พี. เซอร์วิส เอ็นจิ...
# 790287                                  ร้านรัตนพูนทรัพย์
# 790288                           ชัยอมรอลูมินั่มแอนด์กลาส
# 790289                              โรงพิมพ์พัฒนาการพิมพ์
# 790290                                    บึงกาฬอิงท์เจ็ท
# 790291                                   ร้านบึงกาฬไดนาโม
# 790292                ห้างหุ้นส่วนจำกัด อู่เปี๊ยกเซอร์วิส
# 790293                                    บึงกาฬอิงท์เจ็ท
# 790294                                     ร้านเจนพาณิชย์
# 790295                              นายเด่นชัย พงษ์หนองโน
# 790296                                 นายลำเนาว์  เพ็งมี
# 790297                                 นางแช่ม  บุตรเจริญ
# 790298                                     นาง พณิฎา พยอม
# 790299                               ร้านโอฬารบึงกาฬ 2011
# 790300                                     ร้าน ส.การช่าง
# 790301                   ห้างหุ้นส่วนจำกัด พันธ์ศักดิ์ 44
# 790302                         บริษัท โตโยต้าบึงกาฬ จำกัด
# 790303                 บริษัท บึงกาฬเฟอร์นิเจอร์ 77 จำกัด
# 790304                                    บึงกาฬอิงท์เจ็ท
# 790305              บริษัท สยามโกลบอลเฮ้าส์ จำกัด (มหาชน)
# 790306                 บริษัท บึงกาฬเฟอร์นิเจอร์ 77 จำกัด
#
#                             dept_name                  dept_sub_name  \
# 0       องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 1       องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 2       องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 3       องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 4       องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 5       องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 6       องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 7       องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 8       องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 9       องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 10      องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 11      องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 12      องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 13      องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 14      องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 15      องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 16      องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 17      องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 18      องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 19      องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 20      องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 21      องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 22      องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 23      องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 24      องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 25      องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 26      องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 27      องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 28      องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# 29      องค์การบริหารส่วนตำบลโนนสว่าง  องค์การบริหารส่วนตำบลโนนสว่าง
# ...                               ...                            ...
# 790277              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790278              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790279              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790280              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790281              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790282              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790283              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790284              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790285              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790286              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790287              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790288              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790289              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790290              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790291              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790292              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790293              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790294              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790295              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790296              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790297              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790298              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790299              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790300              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790301              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790302              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790303              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790304              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790305              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
# 790306              เทศบาลตำบลวิศิษฐ์              เทศบาลตำบลวิศิษฐ์
#
#              district  ...                                       project_name  \
# 0       เมืองร้อยเอ็ด  ...  ซื้ออาหารเสริม (นม) โครงการ จำนวน 4 แห่ง ศูนย์...
# 1       เมืองร้อยเอ็ด  ...  ซื้อวัสดุเชื่อเพลิงและหล่อลื่น เพื่อใช้ในการปฏ...
# 2       เมืองร้อยเอ็ด  ...  จ้างเหมาตามโครงการก่อสร้างถนนคอนกรีตเสริมเหล็ก...
# 3       เมืองร้อยเอ็ด  ...  จ้างเหมาตามโครงการก่อสร้างถนนดิน  หมู่ที่ 10 บ...
# 4       เมืองร้อยเอ็ด  ...  จ้างเหมาตามโครงการซ่อมแซมถนนดินลูกรัง  บ้านส้ม...
# 5       เมืองร้อยเอ็ด  ...  จ้างเหมาตามโครงการลงดินลูกรังซ่อมแซมถนนสายสองห...
# 6       เมืองร้อยเอ็ด  ...  จ้างจ้างเหมาตามโครงการซ่อมแซมคันกั้นลำห้วยแล้ง...
# 7       เมืองร้อยเอ็ด  ...  จ้างเหมาคนงานทั่วไป  เป็นผู้ปฏิบัติหน้าที่ต่าง...
# 8       เมืองร้อยเอ็ด  ...  ซื้อวัสดุวิทยาศาสตร์หรือการแพทย์  จำนวน 2  ราย...
# 9       เมืองร้อยเอ็ด  ...  จ้างจ้างเหมาบริการทำความสะอาดในสถานที่ราชการ โ...
# 10      เมืองร้อยเอ็ด  ...  จ้างเหมาบริการคนงานทั่วไป  โดยมีหน้าที่รับผิดช...
# 11      เมืองร้อยเอ็ด  ...  จ้างเหมาบริการงานสถิติข้อมูลสารสนเทศ โดยมีหน้า...
# 12      เมืองร้อยเอ็ด  ...  จ้างเหมาบริการอาสาสมัครกู้ชีพ โดยให้ปฏิบัติหน้...
# 13      เมืองร้อยเอ็ด  ...  จ้างเหมาบริการอาสาสมัครกู้ชีพ โดยให้ปฏิบัติหน้...
# 14      เมืองร้อยเอ็ด  ...  จ้างเหมาบริการรักษาความปลอดภัยในสถานที่ราชการ ...
# 15      เมืองร้อยเอ็ด  ...  จ้างเหมาบริการอาสาสมัครกู้ชีพ โดยให้ปฏิบัติหน้...
# 16      เมืองร้อยเอ็ด  ...  จ้างเหมาบริการอาสาสมัครกู้ชีพ โดยให้ปฏิบัติหน้...
# 17      เมืองร้อยเอ็ด  ...  ซื้อวัสดุไฟฟ้าและวิทยุ จำนวน 18 รายการ โดยวิธี...
# 18      เมืองร้อยเอ็ด  ...  ซื้อโครงการช่วยเหลือผู้ประสบภัย(วาตภัย) ในเขตพ...
# 19      เมืองร้อยเอ็ด  ...  ซื้อครุภัณฑ์คอมพิวเตอร์  สำหรับประมวลผล แบบที่...
# 20      เมืองร้อยเอ็ด  ...  ซื้อวัสดุสำนักงาน  จำนวน  27  รายการ โดยวิธีเฉ...
# 21      เมืองร้อยเอ็ด  ...  ซื้อวัสดุก่อสร้าง  จำนวน  27  รายการ โดยวิธีเฉ...
# 22      เมืองร้อยเอ็ด  ...  ซื้อเครื่องมัลติมีเดียโปรเจคเตอร์ โดยวิธีเฉพาะ...
# 23      เมืองร้อยเอ็ด  ...  ซื้อวัสดุ-อุปกรณ์ และค่าใช้จ่ายอื่นที่เกี่ยวข้...
# 24      เมืองร้อยเอ็ด  ...  ซื้อเครื่องชุมสายโทรศัพท์ (ตู้สาขา) พร้อมติดตั...
# 25      เมืองร้อยเอ็ด  ...  ซื้อวัสดุคอมพิวเตอร์  จำนวน 2 รายการ โดยวิธีเฉ...
# 26      เมืองร้อยเอ็ด  ...  ซื้อวัสดุสำนักงาน  จำนวน  28  รายการ โดยวิธีเฉ...
# 27      เมืองร้อยเอ็ด  ...  ซื้อวัสดุคอมพิวเตอร์  จำนวน  2  รา่ยการ โดยวิธ...
# 28      เมืองร้อยเอ็ด  ...  จ้างจ้างเหมาตามโครงการซ่อมแซมคันกั้นลำห้วยแล้ง...
# 29      เมืองร้อยเอ็ด  ...  ซื้อวัสดุคอมพิวเตอร์  จำนวน 5 รายการ โดยวิธีเฉ...
# ...               ...  ...                                                ...
# 790277    เมืองบึงกาฬ  ...  จ้างจ้างเหมาทำอาหารกลางวัน โครงการสืบสานพระราช...
# 790278    เมืองบึงกาฬ  ...  จ้างจ้างเหมาทำอาหารกลางวัน โครงการรณรงค์ป้องกั...
# 790279    เมืองบึงกาฬ  ...  ซื้อจัดซื้อวัสดุเพื่อซ่อมแซมทรัพย์สิน จำนวน 9 ...
# 790280    เมืองบึงกาฬ  ...  ซื้อจัดซื้อท่อระบายน้ำ เพื่อซ่อมแซมถนนในเขตเทศ...
# 790281    เมืองบึงกาฬ  ...  ซื้อจัดซื้อวัสดุงานบ้านงานครัว จำนวน 2 รายการ ...
# 790282    เมืองบึงกาฬ  ...  ซื้อจัดซื้อวัสดุสำนักงาน  (โครงการจัดทำเอกสารเ...
# 790283    เมืองบึงกาฬ  ...  ซื้อครุภัณฑ์สำนักงาน เก้าอี้นั่งทำงาน จำนวน 2 ...
# 790284    เมืองบึงกาฬ  ...  ซื้อจัดชื้อพัดลมแบบติดผนัง  ขนาด 18 นิ้ว จำนวน...
# 790285    เมืองบึงกาฬ  ...  ซื้อจัดซื้อวัสดุคอมพิวเตอร์ (หมึกพิมพ์) จำนวน ...
# 790286    เมืองบึงกาฬ  ...  จ้างจ้างซ่อมแซมรถใช้งานส่วนกลาง รถตักหน้าขุดหล...
# 790287    เมืองบึงกาฬ  ...  ซื้อจัดซื้อท่อระบายน้ำเพื่อซ่อมแซมถนนและสะพาน ...
# 790288    เมืองบึงกาฬ  ...  ซื้อคอนกรีตผสมเสร็จ(240) จำนวน 3.5 คิว โดยวิธี...
# 790289    เมืองบึงกาฬ  ...  ซื้อจัดซื้อใบเสร็จรับเงินค่าบริการสูบน้ำด้วยไฟ...
# 790290    เมืองบึงกาฬ  ...  จ้างจ้างทำป้ายไวนิลและเอกสารแผ่นพับประชาสัมพัน...
# 790291    เมืองบึงกาฬ  ...  จ้างจ้างซ่อมแซมรถบรรทุกขยะมูลฝอย ทะเบียน 80-20...
# 790292    เมืองบึงกาฬ  ...  จ้างจ้างเหมาบริการ รถยนต์ส่วนกลาง ทะเบียน กก 8...
# 790293    เมืองบึงกาฬ  ...  จ้างจัดจ้างทำป้าย ตามโครงการแข่งขันเรือยาวประเ...
# 790294    เมืองบึงกาฬ  ...  จ้างเหมาบริการ จัดเอกสารประกอบการฝึกอบรมโครงกา...
# 790295    เมืองบึงกาฬ  ...  จ้างจัดจ้างประกอบอาหารกลางวันและอาหารว่าง ตามโ...
# 790296    เมืองบึงกาฬ  ...  ซื้อจัดซื้อวัสดุงานบ้านงาน จำนวน 2 รายการ โดยว...
# 790297    เมืองบึงกาฬ  ...  จ้างจ้างเหมาบริการทำอาหารว่างและเครื่องดื่ม ,อ...
# 790298    เมืองบึงกาฬ  ...        ซื้อจัดซื้อวัสดุสำนักงาน โดยวิธีเฉพาะเจาะจง
# 790299    เมืองบึงกาฬ  ...  ซื้อจัดซื้อวัสดุสำนักงาน จำนวน 14 รายการ โดยวิ...
# 790300    เมืองบึงกาฬ  ...  จ้างจ้างซ่อมแวมรถบรรทุกขยะมูลฝอย ทะเบียน 80-20...
# 790301    เมืองบึงกาฬ  ...  จ้างทำป้ายไวนิลพระบรมฉายาลักษณ์ร.10 และตราสัญล...
# 790302    เมืองบึงกาฬ  ...  จ้างเหมาบริการ ตรวจเช็คระยะรถยนต์ส่วนกลาง ทะเบ...
# 790303    เมืองบึงกาฬ  ...  ซื้อจัดซื้อวัสดุงานบ้านงานครัว จำนวน 2 รายการ ...
# 790304    เมืองบึงกาฬ  ...  จ้างจ้างจัดทำคู่มือให้ความรู้การป้องกันแก้ไขปั...
# 790305    เมืองบึงกาฬ  ...  ซื้อจัดซื้อยางมะตอย และวัสดุเพื่อซ่อมแซมทรัพย์...
# 790306    เมืองบึงกาฬ  ...  ซื้อจัดซื้อครุภัณฑ์สำนักงาน ตู้เหล็ก 2 ชั้น แบ...
#
#           project_status         project_type_name  province  \
# 0       ระหว่างดำเนินการ                      ซื้อ  ร้อยเอ็ด
# 1       ระหว่างดำเนินการ                      ซื้อ  ร้อยเอ็ด
# 2       ระหว่างดำเนินการ              จ้างก่อสร้าง  ร้อยเอ็ด
# 3       ระหว่างดำเนินการ              จ้างก่อสร้าง  ร้อยเอ็ด
# 4       ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ  ร้อยเอ็ด
# 5       ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ  ร้อยเอ็ด
# 6       ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ  ร้อยเอ็ด
# 7       ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ  ร้อยเอ็ด
# 8       ระหว่างดำเนินการ                      ซื้อ  ร้อยเอ็ด
# 9       ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ  ร้อยเอ็ด
# 10      ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ  ร้อยเอ็ด
# 11      ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ  ร้อยเอ็ด
# 12      ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ  ร้อยเอ็ด
# 13      ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ  ร้อยเอ็ด
# 14      ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ  ร้อยเอ็ด
# 15      ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ  ร้อยเอ็ด
# 16      ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ  ร้อยเอ็ด
# 17      ระหว่างดำเนินการ                      ซื้อ  ร้อยเอ็ด
# 18      ระหว่างดำเนินการ                      ซื้อ  ร้อยเอ็ด
# 19          สิ้นสุดสัญญา                      ซื้อ  ร้อยเอ็ด
# 20      ระหว่างดำเนินการ                      ซื้อ  ร้อยเอ็ด
# 21      ระหว่างดำเนินการ                      ซื้อ  ร้อยเอ็ด
# 22      ระหว่างดำเนินการ                      ซื้อ  ร้อยเอ็ด
# 23          สิ้นสุดสัญญา                      ซื้อ  ร้อยเอ็ด
# 24      ระหว่างดำเนินการ                      ซื้อ  ร้อยเอ็ด
# 25      ระหว่างดำเนินการ                      ซื้อ  ร้อยเอ็ด
# 26      ระหว่างดำเนินการ                      ซื้อ  ร้อยเอ็ด
# 27      ระหว่างดำเนินการ                      ซื้อ  ร้อยเอ็ด
# 28      ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ  ร้อยเอ็ด
# 29          สิ้นสุดสัญญา                      ซื้อ  ร้อยเอ็ด
# ...                  ...                       ...       ...
# 790277  ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ    บึงกาฬ
# 790278  ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ    บึงกาฬ
# 790279  ระหว่างดำเนินการ                      ซื้อ    บึงกาฬ
# 790280  ระหว่างดำเนินการ                      ซื้อ    บึงกาฬ
# 790281  ระหว่างดำเนินการ                      ซื้อ    บึงกาฬ
# 790282  ระหว่างดำเนินการ                      ซื้อ    บึงกาฬ
# 790283  ระหว่างดำเนินการ                      ซื้อ    บึงกาฬ
# 790284  ระหว่างดำเนินการ                      ซื้อ    บึงกาฬ
# 790285  ระหว่างดำเนินการ                      ซื้อ    บึงกาฬ
# 790286  ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ    บึงกาฬ
# 790287  ระหว่างดำเนินการ                      ซื้อ    บึงกาฬ
# 790288  ระหว่างดำเนินการ                      ซื้อ    บึงกาฬ
# 790289  ระหว่างดำเนินการ                      ซื้อ    บึงกาฬ
# 790290  ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ    บึงกาฬ
# 790291  ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ    บึงกาฬ
# 790292  ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ    บึงกาฬ
# 790293  ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ    บึงกาฬ
# 790294  ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ    บึงกาฬ
# 790295  ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ    บึงกาฬ
# 790296  ระหว่างดำเนินการ                      ซื้อ    บึงกาฬ
# 790297  ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ    บึงกาฬ
# 790298  ระหว่างดำเนินการ                      ซื้อ    บึงกาฬ
# 790299  ระหว่างดำเนินการ                      ซื้อ    บึงกาฬ
# 790300  ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ    บึงกาฬ
# 790301  ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ    บึงกาฬ
# 790302  ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ    บึงกาฬ
# 790303  ระหว่างดำเนินการ                      ซื้อ    บึงกาฬ
# 790304  ระหว่างดำเนินการ  จ้างทำของ/จ้างเหมาบริการ    บึงกาฬ
# 790305  ระหว่างดำเนินการ                      ซื้อ    บึงกาฬ
# 790306  ระหว่างดำเนินการ                      ซื้อ    บึงกาฬ
#
#        purchase_method_name subdistrict sum_price_agree transaction_date  \
# 0               เฉพาะเจาะจง     ในเมือง        332323.0        8 พ.ย. 60
# 1               เฉพาะเจาะจง     ในเมือง        320000.0       17 ต.ค. 60
# 2               เฉพาะเจาะจง     ในเมือง        242000.0       21 ก.ย. 61
# 3               เฉพาะเจาะจง     ในเมือง        126100.0       15 ม.ค. 61
# 4               เฉพาะเจาะจง     ในเมือง        114800.0       24 ม.ค. 61
# 5               เฉพาะเจาะจง     ในเมือง        113000.0       30 ม.ค. 61
# 6               เฉพาะเจาะจง     ในเมือง         66300.0       2 เม.ย. 61
# 7               เฉพาะเจาะจง     ในเมือง         54000.0      29 มี.ค. 61
# 8               เฉพาะเจาะจง     ในเมือง         54000.0        7 พ.ค. 61
# 9               เฉพาะเจาะจง     ในเมือง         54000.0        1 ก.พ. 61
# 10              เฉพาะเจาะจง     ในเมือง         54000.0      30 มี.ค. 61
# 11              เฉพาะเจาะจง     ในเมือง         54000.0      30 มี.ค. 61
# 12              เฉพาะเจาะจง     ในเมือง         54000.0      29 มี.ค. 61
# 13              เฉพาะเจาะจง     ในเมือง         54000.0      29 มี.ค. 61
# 14              เฉพาะเจาะจง     ในเมือง         54000.0        1 ก.พ. 61
# 15              เฉพาะเจาะจง     ในเมือง         54000.0      29 มี.ค. 61
# 16              เฉพาะเจาะจง     ในเมือง         54000.0      29 มี.ค. 61
# 17              เฉพาะเจาะจง     ในเมือง         47264.0        9 ก.ค. 61
# 18              เฉพาะเจาะจง     ในเมือง         45364.0        4 พ.ค. 61
# 19              เฉพาะเจาะจง     ในเมือง         44000.0       20 ต.ค. 60
# 20              เฉพาะเจาะจง     ในเมือง         37670.0       27 ก.ย. 61
# 21              เฉพาะเจาะจง     ในเมือง         36893.0       11 ก.ย. 61
# 22              เฉพาะเจาะจง     ในเมือง         36000.0       22 พ.ค. 61
# 23              เฉพาะเจาะจง     ในเมือง         30000.0       11 ม.ค. 61
# 24              เฉพาะเจาะจง     ในเมือง         27000.0       20 ก.ย. 61
# 25              เฉพาะเจาะจง     ในเมือง         27000.0       9 เม.ย. 61
# 26              เฉพาะเจาะจง     ในเมือง         23597.0       4 เม.ย. 61
# 27              เฉพาะเจาะจง     ในเมือง         23450.0       17 ก.ย. 61
# 28              เฉพาะเจาะจง     ในเมือง         22600.0       2 เม.ย. 61
# 29              เฉพาะเจาะจง     ในเมือง         22380.0        5 ม.ค. 61
# ...                     ...         ...             ...              ...
# 790277          เฉพาะเจาะจง     วิศิษฐ์          7500.0       24 ก.ย. 61
# 790278          เฉพาะเจาะจง     วิศิษฐ์          7500.0       21 ก.ย. 61
# 790279          เฉพาะเจาะจง     วิศิษฐ์          7404.0       14 ส.ค. 61
# 790280          เฉพาะเจาะจง     วิศิษฐ์          7360.0        8 ส.ค. 61
# 790281          เฉพาะเจาะจง     วิศิษฐ์          7260.0       3 เม.ย. 61
# 790282          เฉพาะเจาะจง     วิศิษฐ์          7100.0       19 ธ.ค. 60
# 790283          เฉพาะเจาะจง     วิศิษฐ์          7000.0       27 ส.ค. 61
# 790284          เฉพาะเจาะจง     วิศิษฐ์          7000.0      15 มี.ค. 61
# 790285          เฉพาะเจาะจง     วิศิษฐ์          6950.0      12 มี.ค. 61
# 790286          เฉพาะเจาะจง     วิศิษฐ์          6934.0       31 ก.ค. 61
# 790287          เฉพาะเจาะจง     วิศิษฐ์          6889.0       24 พ.ค. 61
# 790288          เฉพาะเจาะจง     วิศิษฐ์          6825.0       14 ส.ค. 61
# 790289          เฉพาะเจาะจง     วิศิษฐ์          6600.0      11 มิ.ย. 61
# 790290          เฉพาะเจาะจง     วิศิษฐ์          6550.0       25 พ.ค. 61
# 790291          เฉพาะเจาะจง     วิศิษฐ์          6500.0       15 ส.ค. 61
# 790292          เฉพาะเจาะจง     วิศิษฐ์          6500.0       5 เม.ย. 61
# 790293          เฉพาะเจาะจง     วิศิษฐ์          6450.0       26 ก.ค. 61
# 790294          เฉพาะเจาะจง     วิศิษฐ์          6400.0       20 ก.ย. 61
# 790295          เฉพาะเจาะจง     วิศิษฐ์          6000.0       21 ส.ค. 61
# 790296          เฉพาะเจาะจง     วิศิษฐ์          6000.0       20 ก.พ. 61
# 790297          เฉพาะเจาะจง     วิศิษฐ์          6000.0       11 ก.ค. 61
# 790298          เฉพาะเจาะจง     วิศิษฐ์          5756.0      18 เม.ย. 61
# 790299          เฉพาะเจาะจง     วิศิษฐ์          5608.0      14 มิ.ย. 61
# 790300          เฉพาะเจาะจง     วิศิษฐ์          5550.0       23 ก.ค. 61
# 790301          เฉพาะเจาะจง     วิศิษฐ์          5500.0        2 ส.ค. 61
# 790302          เฉพาะเจาะจง     วิศิษฐ์          5318.0       22 ก.พ. 61
# 790303          เฉพาะเจาะจง     วิศิษฐ์          5280.0        5 ก.ย. 61
# 790304          เฉพาะเจาะจง     วิศิษฐ์          5250.0       21 ก.ย. 61
# 790305          เฉพาะเจาะจง     วิศิษฐ์          5230.0       18 ก.ย. 61
# 790306          เฉพาะเจาะจง     วิศิษฐ์          5000.0       27 ส.ค. 61
#
#            winner_tin              region
# 0       0455535000091  ตะวันออกเฉียงเหนือ
# 1       3450200645821  ตะวันออกเฉียงเหนือ
# 2       0453538000804  ตะวันออกเฉียงเหนือ
# 3       3450400685311  ตะวันออกเฉียงเหนือ
# 4       0453548000653  ตะวันออกเฉียงเหนือ
# 5       0453548000653  ตะวันออกเฉียงเหนือ
# 6       3450200683439  ตะวันออกเฉียงเหนือ
# 7       5450200051188  ตะวันออกเฉียงเหนือ
# 8       3400700834444  ตะวันออกเฉียงเหนือ
# 9       3450200571495  ตะวันออกเฉียงเหนือ
# 10      2570100022351  ตะวันออกเฉียงเหนือ
# 11      1450200244129  ตะวันออกเฉียงเหนือ
# 12      3450200578481  ตะวันออกเฉียงเหนือ
# 13      3450400201900  ตะวันออกเฉียงเหนือ
# 14      5450200017206  ตะวันออกเฉียงเหนือ
# 15      1450200026407  ตะวันออกเฉียงเหนือ
# 16      5450200056074  ตะวันออกเฉียงเหนือ
# 17      3450400291267  ตะวันออกเฉียงเหนือ
# 18      3450400291267  ตะวันออกเฉียงเหนือ
# 19      0453539000069  ตะวันออกเฉียงเหนือ
# 20      3450400290694  ตะวันออกเฉียงเหนือ
# 21      3450400292573  ตะวันออกเฉียงเหนือ
# 22      0455553000161  ตะวันออกเฉียงเหนือ
# 23      3450800374496  ตะวันออกเฉียงเหนือ
# 24      3409900571810  ตะวันออกเฉียงเหนือ
# 25      0453539000069  ตะวันออกเฉียงเหนือ
# 26      3450400292573  ตะวันออกเฉียงเหนือ
# 27      3450400290694  ตะวันออกเฉียงเหนือ
# 28      3450200683439  ตะวันออกเฉียงเหนือ
# 29      0455546000143  ตะวันออกเฉียงเหนือ
# ...               ...                 ...
# 790277  1430300166642  ตะวันออกเฉียงเหนือ
# 790278  1430300166642  ตะวันออกเฉียงเหนือ
# 790279  0433533000199  ตะวันออกเฉียงเหนือ
# 790280  3430300511681  ตะวันออกเฉียงเหนือ
# 790281  3430300864681  ตะวันออกเฉียงเหนือ
# 790282  3430300864681  ตะวันออกเฉียงเหนือ
# 790283  0385560000369  ตะวันออกเฉียงเหนือ
# 790284  3430700113364  ตะวันออกเฉียงเหนือ
# 790285  1430400108202  ตะวันออกเฉียงเหนือ
# 790286  0413560001893  ตะวันออกเฉียงเหนือ
# 790287  3430300511681  ตะวันออกเฉียงเหนือ
# 790288  0433551000898  ตะวันออกเฉียงเหนือ
# 790289  3480100140182  ตะวันออกเฉียงเหนือ
# 790290  3431000170412  ตะวันออกเฉียงเหนือ
# 790291  3430301083771  ตะวันออกเฉียงเหนือ
# 790292  0383560000847  ตะวันออกเฉียงเหนือ
# 790293  3431000170412  ตะวันออกเฉียงเหนือ
# 790294  3430300862521  ตะวันออกเฉียงเหนือ
# 790295  3430300027690  ตะวันออกเฉียงเหนือ
# 790296              -  ตะวันออกเฉียงเหนือ
# 790297  2410400018384  ตะวันออกเฉียงเหนือ
# 790298  3430300864681  ตะวันออกเฉียงเหนือ
# 790299  3430300864681  ตะวันออกเฉียงเหนือ
# 790300  3430300581182  ตะวันออกเฉียงเหนือ
# 790301  0383560001100  ตะวันออกเฉียงเหนือ
# 790302  0385555000062  ตะวันออกเฉียงเหนือ
# 790303  0385560000369  ตะวันออกเฉียงเหนือ
# 790304  3431000170412  ตะวันออกเฉียงเหนือ
# 790305  0107551000029  ตะวันออกเฉียงเหนือ
# 790306  0385560000369  ตะวันออกเฉียงเหนือ
#
# [790307 rows x 24 columns]

# %% [markdown]
# # Global Statistics

# %%
global_stats = dict(
    totalProjects = len(df_projects), 
    sumProjectValue = df_projects.sum_price_agree.sum()
)

# todo civil projects
global_stats['totalCivilProjects'] = global_stats['totalProjects'] * 0.8
global_stats['sumCivilProjectValue'] = global_stats['sumProjectValue'] * 0.8

print(global_stats)

with open(prepend_path("global_stats.json"), "w") as fh:
    json.dump(global_stats, fh)
# Out:
# {'totalProjects': 790307, 'sumProjectValue': 92805846856.0, 'totalCivilProjects': 632245.6000000001, 'sumCivilProjectValue': 74244677484.8}

# %% [markdown]
# # Procurement Method Statistics

# %%
df_proc_med_stats = df_projects.groupby("purchase_method_name")["sum_price_agree"]


df_proc_med_stats_merged = df_proc_med_stats.count().reset_index().rename(columns={'sum_price_agree':'totalProjects'})\
    .merge(df_proc_med_stats.sum().reset_index().rename(columns={'sum_price_agree':'totalProjectValue'}), on="purchase_method_name")


with open(prepend_path("procurement_methods_stats.json"), "w") as fh:
    json.dump(df_proc_med_stats_merged.to_dict("record"), fh, ensure_ascii=False)

# %%
df_proc_med_stats.count().reset_index()
# Out:
#                      purchase_method_name  sum_price_agree
# 0                               กรณีพิเศษ                1
# 1                                คัดเลือก                4
# 2         จ้างที่ปรึกษาโดยวิธีเฉพาะเจาะจง                8
# 3                                ตกลงราคา               14
# 4  ประกวดราคาด้วยวิธีการทางอิเล็กทรอนิกส์                2
# 5    ประกวดราคาอิเล็กทรอนิกส์ (e-bidding)              157
# 6                                   พิเศษ                1
# 7                                 สอบราคา                1
# 8                             เฉพาะเจาะจง             9812

# %% [markdown]
# # Authority Statistics

# %%
df_local_author_raw = df_projects
df_local_author_stats = df_local_author_raw.groupby(["dept_name", "province"])["sum_price_agree"]

df_local_author_stats.count().reset_index().rename(columns={'sum_price_agree':'totalProjects'})


df_local_author_stats = df_local_author_stats.count().reset_index().rename(columns={'sum_price_agree':'totalProjects'})\
    .merge(df_local_author_stats.sum().reset_index().rename(columns={'sum_price_agree':'totalProjectValue'}), on=['dept_name', 'province'])

df_local_author_stats[:10]


local_author_stats_data = dict()

for r in df_local_author_stats.to_dict("record"):
    r['methodStats'] = dict()
    local_author_stats_data['%s-%s' % (r['dept_name'], r['province'])] = r

# %%
df_local_author_method_stats = df_local_author_raw.groupby(["dept_name", "province", "purchase_method_name"])["sum_price_agree"]

df_local_author_method_stats_merged = df_local_author_method_stats.count().reset_index().rename(columns={'sum_price_agree':'totalProjects'}) \
    .merge(df_local_author_method_stats.sum().reset_index().rename(columns={'sum_price_agree':'totalProjectValue'}), on=['dept_name', 'province', 'purchase_method_name'])

for r in df_local_author_method_stats_merged.to_dict("record"):
    key = '%s-%s' % (r['dept_name'], r['province'])
    local_author_stats_data[key]['methodStats'][r['purchase_method_name']] = dict(
        count=r['totalProjects'], value=r['totalProjectValue']
    )
    if r['purchase_method_name'] == "เฉพาะเจาะจง":
        local_author_stats_data[key]['specialProcurementCount'] = r['totalProjects']
    else: 
        local_author_stats_data[key]['specialProcurementCount'] = 0

# %%
with open(prepend_path("local_authority_stats.json"), "w") as fh:
    sorted_local_author_stats_data =  sorted(local_author_stats_data.values(), key = lambda x: -x['specialProcurementCount'])
    
    json.dump(sorted_local_author_stats_data[:100], fh, ensure_ascii=False)

# %% [markdown]
# # Company Statistics

# %%
thresdhold = 1e8

# %%
filter_names = [
#     "สหกรณ์โคนมวังน้ำเย็น จำกัด"
    "something"
]

df_projects_have_comp = df_projects[~df_projects.corporate_name.isna()]
df_projects_have_comp = df_projects_have_comp[~df_projects_have_comp.corporate_name.str.contains("|".join(filter_names))]

# %%
df_company_stats = df_projects_have_comp.groupby(["corporate_name"])["sum_price_agree"]

df_company_stats_merged = df_company_stats.count().reset_index().rename(columns={'sum_price_agree':'totalProjects'}) \
    .merge(df_company_stats.sum().reset_index().rename(columns={'sum_price_agree':'totalProjectValue'}), on=['corporate_name'])

# %%
df_company_stats_selected = df_company_stats_merged[df_company_stats_merged.totalProjectValue > thresdhold]

# %%
df_company_stats_selected[:5]
# Out:
#                             corporate_name  totalProjects  totalProjectValue
# 1892   กิจการร่วมค้า ชัยภัสร์ คอนสตรัคชั่น              1        154800000.0
# 1897             กิจการร่วมค้า บ้านค่ายปภพ              1        252600000.0
# 1899              กิจการร่วมค้า ภรประสิทธิ              1        117500000.0
# 99450        บริษัท  คันทรีเฟรชแดรี่ จำกัด           1034        314508523.0
# 99474      บริษัท  ชมภูพลอุตสาหกรรม  จำกัด             22        102302579.0

# %%
company_stats_data = dict()

for r in df_company_stats_selected.to_dict("record"):
    r['methodStats'] = dict()
    r['regionCounts'] = []
    r['projectInsights'] = []
    company_stats_data[r['corporate_name']] = r

# %%
df_project_join_selected_company = df_projects.merge(df_company_stats_selected, on=['corporate_name'], how="left")
df_project_join_selected_company = df_project_join_selected_company[df_project_join_selected_company.totalProjects > 0]

# %%
df_company_method_stats = df_project_join_selected_company.groupby(["corporate_name", "purchase_method_name"])["sum_price_agree"]

df_company_method_stats_merged = df_company_method_stats.count().reset_index().rename(columns={'sum_price_agree':'totalProjects'}) \
    .merge(df_company_method_stats.sum().reset_index().rename(columns={'sum_price_agree':'totalProjectValue'}), on=['corporate_name', 'purchase_method_name'])

for r in df_company_method_stats_merged.to_dict("record"):
    key = r['corporate_name']
    
    company_stats_data[key]['methodStats'][r['purchase_method_name']] = dict(
        count=r['totalProjects'], value=r['totalProjectValue']
    )

# %%
df_company_region_stats = df_project_join_selected_company.groupby(["corporate_name", "region"])["sum_price_agree"]

df_company_region_stats_flattened = df_company_region_stats.count().reset_index().rename(columns={'sum_price_agree': 'count'})

for r in df_company_region_stats_flattened.to_dict("record"):
    company_stats_data[r['corporate_name']]['regionCounts'].append(dict(name=r['region'], count=r['count']))

# %%
df_tins = df_project_join_selected_company[['corporate_name', 'winner_tin']].drop_duplicates()

name_to_tins = dict(zip(df_tins['corporate_name'].values, df_tins['winner_tin'].values))

# %%
df_company_project_insight = df_project_join_selected_company.groupby(["corporate_name", "province", "purchase_method_name"])["sum_price_agree"]

df_company_project_insight_flattened = df_company_project_insight.sum().reset_index().rename(columns={'sum_price_agree': 'value'})

for r in df_company_project_insight_flattened.to_dict("record"):
    company_stats_data[r['corporate_name']]['projectInsights'].append(
        dict(source=r['purchase_method_name'], target=r['province'], value=r['value'])
    )

# %%
with open(prepend_path("company_stats.json"), "w") as fh:
    data = []
    
    for d in company_stats_data.values():
        primaryRegion = sorted(d['regionCounts'], key=lambda x: x['count'])[-1]['name']
        d['primaryRegion'] = primaryRegion
        d['tin'] = name_to_tins[d['corporate_name']]
        
        data.append(d)
    json.dump(data, fh, ensure_ascii=False)
