# %%
import pandas as pd

# %%
df_local_admin = pd.read_csv("../data/all-local-administratives.csv", names=['province', 'name'])

# %%
name = set(df_local_admin.name.values)

# %%
data = map(lambda x: dict(name=x), name)

# %%
pd.DataFrame(data).to_csv("../data/org-name-complete.txt", index=False)

# %% [markdown]
# # Check uniq name

# %%
df = pd.read_csv("../data/2019-local-administrative-organization-projects.csv")
# Out:
# /Users/heytitle/projects/jour-d/venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.uniq_name = df.apply(lambda r: '%s-%s' % (r['dept_name'], r['province']), axis=1)

# %%
len(set(df.uniq_name.values))
# Out:
# 6737

# %%
set(df.uniq_name.values)
# Out:
# {'องค์การบริหารส่วนตำบลทุ่งหมอ-สงขลา',
#  'องค์การบริหารส่วนตำบลเขาชะเมา-ระยอง',
#  'องค์การบริหารส่วนตำบลดงหม้อทอง-สกลนคร',
#  'เทศบาลตำบลเหมือง-ชลบุรี',
#  'องค์การบริหารส่วนตำบลไผ่ใหญ่-ลพบุรี',
#  'องค์การบริหารส่วนตำบลบางสวน-ฉะเชิงเทรา',
#  'องค์การบริหารส่วนตำบลศรีมหาโพธิ์-นครปฐม',
#  'องค์การบริหารส่วนตำบลนิคมกระเสียว-สุพรรณบุรี',
#  'องค์การบริหารส่วนตำบลเมืองมาย-ลำปาง',
#  'องค์การบริหารส่วนตำบลสะพุง-ศรีสะเกษ',
#  'เทศบาลเมืองศิลา-ขอนแก่น',
#  'องค์การบริหารส่วนตำบลวังหลวง-แพร่',
#  'เทศบาลตำบลบ้านยาง-นครราชสีมา',
#  'องค์การบริหารส่วนตำบลห้วยยอด-ตรัง',
#  'เทศบาลตำบลสิริเวียงชัย-เชียงราย',
#  'องค์การบริหารส่วนตำบลบ้านบุ่ง-พิจิตร',
#  'เทศบาลตำบลหนองสองห้อง-ขอนแก่น',
#  'เทศบาลตำบลโพธิ์ชัย-ร้อยเอ็ด',
#  'องค์การบริหารส่วนตำบลปลายพระยา-กระบี่',
#  'เทศบาลตำบลนาเมือง-ร้อยเอ็ด',
#  'องค์การบริหารส่วนตำบลกุดใส้จ่อ-มหาสารคาม',
#  'เทศบาลเมืองมุกดาหาร-มุกดาหาร',
#  'องค์การบริหารส่วนตำบลหนองตูม-สุโขทัย',
#  'เทศบาลตำบลทุ่งทอง-ชัยภูมิ',
#  'องค์การบริหารส่วนตำบลแช่ช้าง-เชียงใหม่',
# ...
